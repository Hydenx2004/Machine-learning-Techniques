# %% [markdown]
# <a href="https://colab.research.google.com/github/Hydenx2004/Machine-learning-Techniques/blob/main/Experiment3mlt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
data = load_iris()
X = data.data
y = data.target

# %%
lda = LinearDiscriminantAnalysis(n_components=2)
lda.fit(X, y)
# Out:
# LinearDiscriminantAnalysis(n_components=2)

# %%
X_lda = lda.transform(X)

# %%
plt.scatter(X_lda[:, 0], X_lda[:, 1], c=y)
plt.xlabel('LD1')
plt.ylabel('LD2')
plt.title('Linear Discriminant Analysis')
plt.show()
